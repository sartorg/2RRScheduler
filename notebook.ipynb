# %%
from TwoRRProblem import *
from TwoRROptimization import *

# %%
prob = read_instance("Instances/EarlyInstances/ITC2021_Early_10.xml")

# %%
solve_naive(prob, True)
# Out:
# 20
# 38
# Using license file C:\gurobi\gurobi.lic
# Set parameter CSQueueTimeout to value 300
# Set parameter ServerPassword
# Set parameter TokenServer to value gurobi-ac.sintef.dev
# Changed value of parameter Threads to 2
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Creating binary variables...
# Adding basic 2RR constraints...
# Adding problem specific constraints...
# Num vars: 15920
# Num constraints: 11942
# Writing problem to file...
# Changed value of parameter PoolSolutions to 100
#    Prev: 10  Min: 1  Max: 2000000000  Default: 10
# Changed value of parameter PoolSearchMode to 2
#    Prev: 0  Min: 0  Max: 2  Default: 0
# Changed value of parameter Presolve to 2
#    Prev: -1  Min: -1  Max: 2  Default: -1
# Solving...
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 2 threads
# Optimize a model with 11942 rows, 15920 columns and 239871 nonzeros
# Model fingerprint: 0xce567118
# Variable types: 0 continuous, 15920 integer (15920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 7539 rows and 537 columns
# Presolve time: 1.43s
# Presolved: 4403 rows, 15383 columns, 204026 nonzeros
# Variable types: 0 continuous, 15383 integer (15383 binary)
# Presolve removed 268 rows and 0 columns
# Presolved: 4135 rows, 15383 columns, 186229 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5117    2.9354097e-04   1.487002e+04   0.000000e+00      5s
#     8907    3.8805065e-04   1.166991e+04   0.000000e+00     10s
#    12507    4.1985286e-04   6.444074e+02   0.000000e+00     15s
#    13444    0.0000000e+00   0.000000e+00   0.000000e+00     16s
#    13444    0.0000000e+00   0.000000e+00   0.000000e+00     16s
#
# Root relaxation: objective 0.000000e+00, 13444 iterations, 14.74 seconds
# Total elapsed time = 53.15s
# Total elapsed time = 58.94s
# Total elapsed time = 63.29s
# Total elapsed time = 67.22s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0 1599          -    0.00000      -     -   71s
#      0     0    0.00000    0 1909          -    0.00000      -     -   85s
#      0     0    0.00000    0 1771          -    0.00000      -     -  157s
#      0     0    0.00000    0 1729          -    0.00000      -     -  222s
#      0     0    0.00000    0 1854          -    0.00000      -     -  281s
#      0     0    0.00000    0 1893          -    0.00000      -     -  282s
#      0     0    0.00000    0 1882          -    0.00000      -     -  334s
#      0     0    0.00000    0 1882          -    0.00000      -     -  357s
#      0     2    0.00000    0 1882          -    0.00000      -     -  478s
#      1     4    0.00000    1 1966          -    0.00000      - 39897  486s
#      3     6    0.00000    2 1974          -    0.00000      - 17070  492s
#      5     8    0.00000    3 1986          -    0.00000      - 12353  500s
#      7    10    0.00000    4 1996          -    0.00000      - 10580  508s
#      9    12    0.00000    4 1987          -    0.00000      -  9098  516s
#     11    14    0.00000    5 1978          -    0.00000      -  8869  525s
#     17    47    0.00000    7 1977          -    0.00000      -  6888  545s
#     46    90    0.00000   15 1973          -    0.00000      -  3666  584s
#     89   322    0.00000   26 1930          -    0.00000      -  2831  663s
#    321   385    0.00000  123 1406          -    0.00000      -  1505  719s
#    414   495 infeasible  152               -    0.00000      -  1970  779s
#    544   495 infeasible  179               -    0.00000      -  2112  838s
#    596   553    0.00000  177  995          -    0.00000      -  2615  902s
#    708   607    0.00000  143 1301          -    0.00000      -  2670  969s
#    834   608    0.00000  113 1882          -    0.00000      -  2627  970s
#    836   609    0.00000  105 1599          -    0.00000      -  2621 1090s
#    837   610    0.00000   66 1884          -    0.00000      -  2618 1161s
#    838   611    0.00000  145 1901          -    0.00000      -  2615 1237s
#    839   611    0.00000   21 1568          -    0.00000      -  2612 1318s
#    840   612    0.00000  163 1779          -    0.00000      -  2608 1327s
#    841   613    0.00000  125 1915          -    0.00000      -  2605 1381s
#    842   613    0.00000  126 1981          -    0.00000      -  2602 1392s
#    843   614    0.00000  124 1995          -    0.00000      -  2599 1472s
#    844   615    0.00000   33 2025          -    0.00000      -  2596 1482s
#    845   615    0.00000  174 1958          -    0.00000      -  2593 1545s
#    846   616    0.00000   14 2011          -    0.00000      -  2590 1556s
