# %%
from TwoRRInstance import *

# %%
read_instance("Instances/TestInstances/ITC2021_Test1.xml")
# Out:
# MetaData {}
# Structure {}
# ObjectiveFunction {}
# Resources {}
# Constraints {}
# InstanceName {} Test Instance 1
# DataType {} A
# Contributor {} ITC2021
# Date {'year': '2020', 'month': '10'} None
# Name: Test Instance 1
# Data type: A
# Contributor: ITC2021
# Year: 2020
# Game mode: P
# Objective: SC
# Teams:['Team 0', 'Team 1', 'Team 2', 'Team 3', 'Team 4', 'Team 5']
# Slots:['Slot 0', 'Slot 1', 'Slot 2', 'Slot 3', 'Slot 4', 'Slot 5', 'Slot 6', 'Slot 7', 'Slot 8', 'Slot 9']
# Constraints:
