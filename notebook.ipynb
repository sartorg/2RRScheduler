# %%
from TwoRRProblem import *
from TwoRROptimization import *

# %%
prob = read_instance("Instances/TestInstances/ITC2021_Test4.xml")

# %%
solve_naive(prob)
# Out:
# 6
# 10
# Using license file C:\gurobi\gurobi.lic
# Set parameter CSQueueTimeout to value 300
# Set parameter ServerPassword
# Set parameter TokenServer to value gurobi-ac.sintef.dev
# Changed value of parameter Threads to 2
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Creating binary variables...
# Adding basic 2RR constraints...
# Adding problem specific constraints...
# ['0,3', '2,3', '4,3']
# ['3,1', '3,2', '4,1', '5,1']
# ['0,4', '2,4', '4,5', '5,2']
# ['0,4', '2,3', '4,0']
# ['0,4', '0,5', '1,3', '4,5']
# ['2,0', '3,5', '4,3', '5,1']
# ['5,1', '5,4']
# ['0,3', '1,0', '4,2', '5,1']
# ['4,2']
# ['1,2', '1,4', '4,2', '5,3']
# ['0,2', '1,0', '4,2']
# ['4,2']
# ['1,3', '3,1', '4,5']
# ['1,5', '2,3', '3,0', '5,1']
# ['0,4', '2,4', '3,5', '5,4']
# ['1,2', '1,3', '4,3']
# ['1,0', '3,5', '4,1']
# ['0,1', '0,5', '2,0', '5,3']
# ['0,3', '3,4', '5,1', '5,3']
# ['0,5', '3,2', '5,2']
# Num vars: 1150
# Num constraints: 2068
# Setting the objective...
# Solving...
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 2 threads
# Optimize a model with 2068 rows, 1150 columns and 55817 nonzeros
# Model fingerprint: 0xe28dfb36
# Variable types: 0 continuous, 1150 integer (438 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 2068 rows and 1150 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 4675
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.675000000000e+03, best bound 4.675000000000e+03, gap 0.0000%
# Optimal objective: 4675
# Slot 0:
# (2,0) (3,5) (4,1)
# Slot 1:
# (0,4) (3,1) (5,2)
# Slot 2:
# (0,3) (1,5) (2,4)
# Slot 3:
# (1,2) (4,3) (5,0)
# Slot 4:
# (0,1) (3,2) (5,4)
# Slot 5:
# (1,4) (2,5) (3,0)
# Slot 6:
# (2,1) (4,0) (5,3)
# Slot 7:
# (0,2) (3,4) (5,1)
# Slot 8:
# (1,0) (2,3) (4,5)
# Slot 9:
# (0,5) (1,3) (4,2)
