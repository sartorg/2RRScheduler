# %%
from TwoRRProblem import *
from TwoRROptimization import *

# %%
prob = read_instance("Instances/TestInstances/ITC2021_Test8.xml")

# %%
solve_naive(prob)
# Out:
# 20
# 38
# Using license file C:\gurobi911\gurobi.lic
# Set parameter CSQueueTimeout to value 300
# Set parameter ServerPassword
# Set parameter TokenServer to value gurobi-ac.sintef.dev
# Creating binary variables...
# Adding basic 2RR constraints...
# Adding problem specific constraints...
# Num vars: 15069
# Num constraints: 10943
# Setting the objective...
# Solving...
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 10943 rows, 15069 columns and 201016 nonzeros
# Model fingerprint: 0xd6664fbd
# Variable types: 0 continuous, 15069 integer (14440 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 7247 rows and 68 columns
# Presolve time: 0.50s
# Presolved: 3696 rows, 15001 columns, 183559 nonzeros
# ...
