# %%
from TwoRRInstance import *

# %%
read_instance("Instances/EarlyInstances/ITC2021_Early_1.xml")
# Out:
# MetaData {}
# Structure {}
# ObjectiveFunction {}
# Resources {}
# Constraints {}
# InstanceName {}
# DataType {}
# Contributor {}
# Date {'year': '2020', 'month': '10'}
