# %%
from TwoRRProblem import read_instance
from TwoRRMaster import solve_master
prob = read_instance("Instances/TestInstances/ITC2021_Test1.xml")
solve_master(prob)
# Out:
# Solving problem: Test Instance 1
# Num. teams: 6
# Using license file C:\gurobi911\gurobi.lic
# Set parameter CSQueueTimeout to value 300
# Set parameter ServerPassword
# Set parameter TokenServer to value gurobi-ac.sintef.dev
# Changed value of parameter Threads to 1
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Creating binary variables...
# Adding problem specific constraints...
# Num vars: 185
# Num constraints: 136
# Writing problem to file...
# Changed value of parameter Presolve to 2
#    Prev: -1  Min: -1  Max: 2  Default: -1
# Changed value of parameter Symmetry to 2
#    Prev: -1  Min: -1  Max: 2  Default: -1
# Changed value of parameter GomoryPasses to 1
#    Prev: -1  Min: -1  Max: 2000000000  Default: -1
# Changed value of parameter PrePasses to 2
#    Prev: -1  Min: -1  Max: 2000000000  Default: -1
# Changed value of parameter FeasibilityTol to 1e-09
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Changed value of parameter IntFeasTol to 1e-09
#    Prev: 1e-05  Min: 1e-09  Max: 0.1  Default: 1e-05
# Solving...
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 1 threads
# Optimize a model with 136 rows, 185 columns and 514 nonzeros
# Model fingerprint: 0xd649d3d0
# Variable types: 0 continuous, 185 integer (168 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Finding assignment...
# >>>>Slave: Solving...
# >>>>Slave: Model is infeasible
# Generating lazy cut...
# Presolve removed 24 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 112 rows, 177 columns, 439 nonzeros
# Variable types: 0 continuous, 177 integer (160 binary)
# Presolved: 112 rows, 177 columns, 439 nonzeros
#
#
# Root relaxation: objective 2.000000e+00, 55 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.00000    0    5          -    2.00000      -     -    0s
# Finding assignment...
# >>>>Slave: Solving...
# >>>>Slave: Model is infeasible
# Generating lazy cut...
# Finding assignment...
# >>>>Slave: Solving...
# >>>>Slave: Model is infeasible
# Generating lazy cut...
# Finding assignment...
# >>>>Slave: Solving...
# >>>>Slave: Model is infeasible
# Generating lazy cut...
# Finding assignment...
# >>>>Slave: Solving...
# >>>>Slave: Model is infeasible
# Generating lazy cut...
# Finding assignment...
# >>>>Slave: Solving...
# >>>>Slave: Model is infeasible
# Generating lazy cut...
# *    0     0               0       2.0000000    2.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 1
#   Lazy constraints: 4
#
# Explored 1 nodes (57 simplex iterations) in 0.34 seconds
# Thread count was 1 (of 4 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
#
# User-callback calls 82, time in user-callback 0.26 sec
# Optimal objective: 2
# Team 0:
# A A H A H H A A H A
# Team 1:
# A H A A H A H A H A
# Team 2:
# A A A A A A H A A A
# Team 3:
# H A H H H A H A A H
# Team 4:
# H A A H A A A H A H
# Team 5:
# A H A H A A H A H A
# Writing problem to file...
