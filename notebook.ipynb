# %%
from TwoRRProblem import read_instance
from TwoRRMaster import solve_master
prob = read_instance("Instances/EarlyInstances/ITC2021_Early_10.xml")
solve_master(prob)
# Out:
# Solving problem: Test Instance 1
# Num. teams: 6
# Using license file C:\gurobi\gurobi.lic
# Set parameter CSQueueTimeout to value 300
# Set parameter ServerPassword
# Set parameter TokenServer to value gurobi-ac.sintef.dev
# Changed value of parameter Threads to 1
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Creating binary variables...
# Adding problem specific constraints...
# Num vars: 185
# Num constraints: 136
# Writing problem to file...
# Changed value of parameter Presolve to 2
#    Prev: -1  Min: -1  Max: 2  Default: -1
# Changed value of parameter Symmetry to 2
#    Prev: -1  Min: -1  Max: 2  Default: -1
# Changed value of parameter GomoryPasses to 1
#    Prev: -1  Min: -1  Max: 2000000000  Default: -1
# Changed value of parameter PrePasses to 2
#    Prev: -1  Min: -1  Max: 2000000000  Default: -1
# Solving...
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 136 rows, 185 columns and 514 nonzeros
# Model fingerprint: 0xdc88eb32
# Variable types: 0 continuous, 185 integer (168 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 52 rows and 59 columns
# Presolve time: 0.01s
# Presolved: 84 rows, 126 columns, 339 nonzeros
# Extracted 11 lazy constraints
# Variable types: 0 continuous, 126 integer (120 binary)
# Presolved: 73 rows, 126 columns, 219 nonzeros
#
#
# Root relaxation: objective 1.000000e+00, 33 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.00000    0    8    7.00000    2.00000  71.4%     -    0s
# *    0     0               0       2.0000000    2.00000  0.00%     -    0s
#
# Cutting planes:
#   MIR: 1
#   Lazy constraints: 7
#
# Explored 1 nodes (85 simplex iterations) in 0.09 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Optimal objective: 2
# Slot 0:
#  A   A   A   H   H   H
# Slot 1:
#  H   H   H   H   A   A
# Slot 2:
#  A   A   A   A   A   A
# Slot 3:
#  A   A   H   A   H   H
# Slot 4:
#  A   H   A   H   A   A
# Slot 5:
#  H   A   A   A   A   H
# Slot 6:
#  A   H   H   A   A   A
# Slot 7:
#  H   A   A   A   H   H
# Slot 8:
#  H   H   A   A   A   A
# Slot 9:
#  A   A   H   H   H   H
