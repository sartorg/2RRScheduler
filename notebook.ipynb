# %%
from TwoRRProblem import *
from TwoRROptimization import *

# %%
prob = read_instance("Instances/TestInstances/ITC2021_Test1.xml")

# %%
solve_naive(prob, False)
# Out:
# 6
# 10
# Using license file C:\gurobi\gurobi.lic
# Set parameter CSQueueTimeout to value 300
# Set parameter ServerPassword
# Set parameter TokenServer to value gurobi-ac.sintef.dev
# Changed value of parameter Threads to 2
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Creating binary variables...
# Adding basic 2RR constraints...
# Adding problem specific constraints...
# Num vars: 408
# Num constraints: 457
# Writing problem to file...
# Changed value of parameter Presolve to 2
#    Prev: -1  Min: -1  Max: 2  Default: -1
# Solving...
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 2 threads
# Optimize a model with 457 rows, 408 columns and 4044 nonzeros
# Model fingerprint: 0x0c0edef7
# Variable types: 0 continuous, 408 integer (408 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 184 rows and 34 columns
# Presolve time: 0.01s
# Presolved: 273 rows, 374 columns, 3038 nonzeros
# Variable types: 0 continuous, 374 integer (374 binary)
# Presolve removed 37 rows and 0 columns
# Presolved: 236 rows, 374 columns, 2613 nonzeros
#
#
# Root relaxation: objective 0.000000e+00, 347 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   94          -    0.00000      -     -    0s
#      0     0    0.00000    0  135          -    0.00000      -     -    0s
# H    0     0                       0.0000000    0.00000  0.00%     -    0s
#      0     0    0.00000    0  135    0.00000    0.00000  0.00%     -    0s
#
# Cutting planes:
#   Clique: 4
#   MIR: 4
#   Zero half: 1
#
# Explored 1 nodes (1042 simplex iterations) in 0.18 seconds
# Thread count was 2 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# Optimal objective: 0
# Slot 0:
# (0,4) (1,5) (2,3)
# Slot 1:
# (3,1) (4,2) (5,0)
# Slot 2:
# (0,1) (2,5) (4,3)
# Slot 3:
# (0,2) (1,4) (5,3)
# Slot 4:
# (1,2) (3,0) (4,5)
# Slot 5:
# (0,3) (2,1) (5,4)
# Slot 6:
# (1,0) (3,4) (5,2)
# Slot 7:
# (3,2) (4,0) (5,1)
# Slot 8:
# (0,5) (1,3) (2,4)
# Slot 9:
# (2,0) (3,5) (4,1)
